# %% [markdown]
# ## A-B Testing on the companion bot using an LLM

# %% [markdown]
# Set up

# %%
from openai import OpenAI
import os
import base64
import requests

from collections import Counter

from IPython.display import display, Markdown, Image, HTML


from dotenv import load_dotenv
# Load API key
_ = load_dotenv()

# %%
def query_LLM(messages=None, prompt=None, model='gpt-4o'):

    if messages is None and prompt:
        messages = [{ "role": "user", "content": prompt }]
    elif messages is None:
        return None
        
    completion = client.chat.completions.create(
      model=model,
      messages=messages
    )
    
    response = completion.choices[0].message.content

    return response

# %%
client = OpenAI()

# %% [markdown]
# ### Load product websites
#
# * Here there are two Markdown files that were generated by GPT-4o for a new product that might help individuals and families gain **companion**, entertainment, smart home management, and service on package delivery or pick up!
#
# * **Product general idea description**
# >  A compainion bot that can chat with users and complete assigned tasks
#
# * **Prompt**
# > Generate a product webpage for a new product called [NAME]. [DESCRIPTION]. Include a description and features and testimonials
#
# * **Product names**:
#
# 1. `Companio`
# 2. `Version B`

# %%
import os
from IPython.display import Markdown, display

md_path = "Version_A&B/productA_Companio.md"
base_dir = os.getcwd()

with open(md_path, "r", encoding="utf-8") as f:
    content = f.read()

content = content.replace('src="', 'src="Version_A&B/Images/ProductA_Images/')

display(Markdown(content))
# Out:
# <p align="center">
#   <img src="Version_A&B/Images/ProductA_Images/logo.png" alt="Companio Logo" width="220">
# </p>
#
# # Companio
# **The friendly sidekick for your home and lifestyle.**
#
# <p align="center">
#   <img src="Version_A&B/Images/ProductA_Images/image.png" alt="Companio Logo" width="220">
# </p>
# ---
#
# ## Why Companio?
# Companio isn’t just a gadget — it’s a **companion robot** designed to make everyday life easier, smarter, and more fun.
#
# From fetching snacks to hosting trivia nights, Companio adapts to you and your family’s lifestyle.
#
# ---
#
# ## Key Features
# | 🚚 Smart Pickup & Delivery | 🎥 Always Connected | 🎶 Entertainment Hub |
# |----------------------------|--------------------|----------------------|
# | Fetches food deliveries, packages, or snacks. | Video calls, messages, reminders. | Music, trivia, party host mode. |
#
# | 🕒 Mood Awareness | 🐶 Family-Friendly | 🔋 Autonomous Charging |
# |-------------------|-------------------|------------------------|
# | Adapts to your schedule and preferences. | Pet-safe navigation, washable surfaces, quiet motors. | Returns to dock when low on battery. |
#
# ---
#
# ## Reviews & Endorsements
# > ⭐ *“Companio redefines what a home robot should be — it doesn’t just sit, it acts.”*
# > — Tech Innovators Weekly
#
# > ☕ *“I asked it to bring my coffee. It did. My life is changed.”*
# > — Beta User
#
# > 👨‍👩‍👧 *“Our kids adore Companio. It’s part game console, part helper, part buddy.”*
# > — Parent Review
#
# ---
#
# ## Companio is For Everyone
# - **For families**: *“Bring more fun into the living room. From trivia nights to snack runs, Companio makes memories happen.”*
# - **For professionals**: *“Never miss a call, delivery, or break. Companio keeps your workday smooth and connected.”*
# - **For seniors**: *“Stay connected with loved ones, get helpful reminders, and enjoy companionship every day.”*
# - **For tech lovers**: *“Not just another gadget — Companio is a moving, thinking, friendly assistant with personality.”*
#
# ---
#
# ## Get Started
# 👉 [**See how Companio fits in your life**](#)
#
# <p align="center">
#   <img src="Version_A&B/Images/ProductA_Images/bot.jpg" alt="Companio in action" width="400">
# </p>

# %%
import re, os

def fix_paths(html, base_dir):
    def replace_src(m):
        path = m.group(1)
        if path.startswith("http") or path.startswith("https"):
            return f'src="{path}"'
        return f'src="file://{os.path.join(base_dir, path)}"'

    def replace_href(m):
        path = m.group(1)
        if path.startswith("http") or path.startswith("https"):
            return f'href="{path}"'
        return f'href="file://{os.path.join(base_dir, path)}"'

    html = re.sub(r'src="([^"]+)"', replace_src, html)
    html = re.sub(r'href="([^"]+)"', replace_href, html)
    return html

# %%
from IPython.display import IFrame
html_path = "Version_A&B/VersionB/productB_senti.html"

# Jupyter 通过 /files/ 提供 HTTP 访问
IFrame(src=f"/files/{html_path}", width="100%", height=600)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="/files/Version_A&B/VersionB/productB_senti.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Compare descriptions

# %%
productA = open('Version_A&B/productA_Companio.md').read() 
productB = open('Version_A&B/VersionB/productB_senti.html').read()

# %%
system_prompt = "You are consumer who is a {description}"

rating_prompt = f'''
   Read the websites for each of these two products
   1. Companio
   2. Senti

   {productA}

   ----

   {productB}

   ----
   Pay careful attention to the features, descriptions and user reviews.

   Rate each product on scale of 0 (never buy) to 10 (buy immediately).
   Show just your ratings and which product you prefer.
   Then briefly explain your ratings
'''

# %%
consumers = [
    "student, male, freshman, seeks community",
    "working individual, female, 25 year old, busy schedule",
    "family of four, mom and dad and two daughters",
    "a team in company, 5 people group with a manager"
]

# %%
for consumer in consumers:
    print(f"\n-----\n{consumer}")

    messages = [
       {"role": "system", "content": system_prompt.format(description=consumer)},
       {"role": "system", "content": rating_prompt}
    ]

    response = query_LLM(messages=messages)

    print(response,'\n')
# Out:
# -----
# student, male, freshman, seeks community
# **Ratings:**
#
# - **Companio:** 8/10
# - **Senti:** 7/10
#
# **Preferred Product: Companio**
#
# **Explanation:**
#
# I am a student seeking community, and both products offer features that resonate with my interests.
#
# **Companio:**
# - **Features:** As a freshman, the idea of having a companion robot that can help with mundane tasks like fetching snacks or adding fun to gatherings is quite appealing. The entertainment features like music and trivia nights are particularly attractive as they can enhance social interactions in a dorm setting.
# - **Community Aspect:** Companio's features that promote social activities (e.g., party host mode, game console) seem well-suited to creating a lively and engaging environment, which aligns with my desire to seek community.
# - **Rating Reason:** Given its practical utility and entertainment features that suit a student lifestyle, I rated Companio an 8/10.
#
# **Senti:**
# - **Features:** Senti's focus on emotional connection and companionship is also valuable, especially the ability to share a 'heartbeat' across distances, which could be great for keeping in touch with family or friends who are far away.
# - **Community Aspect:** While the emotional presence is touching, it doesn't quite match the communal or activity-focused environment that Companio offers, which is important for a student experience.
# - **Rating Reason:** Senti offers innovative technology for emotional connection but lacks activity-focused features that align with my community-seeking goals, thus I rated it a 7/10.
#
#
# -----
# working individual, female, 25 year old, busy schedule
# **Ratings:**
#
# 1. **Companio:** 8/10
# 2. **Senti:** 7/10
#
# **Preferred Product:** Companio
#
# **Explanation:**
#
# - **Companio:**
#   - As a busy professional, the idea of having a robot that can fetch snacks, manage deliveries, and host entertainment events like trivia nights is appealing and fits seamlessly into a hectic lifestyle. The ability to adapt to my schedule and preferences adds an extra personal touch. The integration of communication features and being family-friendly with pet-safe navigation is also beneficial. Companio's ability to handle practical tasks gives it an edge for someone who values efficiency and practicality in their daily routine.
#
# - **Senti:**
#   - Senti offers more emotional and companionship features such as reflecting moods with lights and sync heartbeat pulses which are unique and would be appreciated during moments when emotional connection is needed. However, the features seem more oriented towards emotional bonds and rituals rather than practical everyday tasks that help with a busy lifestyle. For someone who values emotional connectivity in long-distance relationships, Senti would be a great fit, but for immediate lifestyle convenience and efficiency, Companio seems to offer more applicable solutions for balancing a busy schedule.
#
#
# -----
# family of four, mom and dad and two daughters
# **Ratings:**
#
# - **Companio Rating: 8/10**
# - **Senti Rating: 7/10**
# - **Preferred Product: Companio**
#
# **Explanation:**
#
# - **Companio:**
#   - **Features**: I appreciate the practical features like smart pickup and delivery, entertainment hub, and family-friendly design. The mood awareness and autonomous charging are also useful for hassle-free operation.
#   - **Family Orientation**: It seems well-suited for a family with kids, as it integrates fun aspects like trivia nights and snack fetching, making it appealing to all family members.
#   - **User Reviews**: Positive feedback from users highlights its usefulness in everyday life, and the integration into family activities makes it an attractive choice for enhancing family time.
#
# - **Senti:**
#   - **Features**: The unique features like mood mirror, shared rhythm, and companion moves offer an emotional and connection-centric experience.
#   - **Target Audience**: While it has thoughtful features for busy families, its emphasis seems more tailored for long-distance relationships and personal companionship rather than family activities.
#   - **User Reviews**: Users note that it enhances emotional presence and connection, which might cater well to distant family members, enhancing interactions but not as central to daily family life.
#
# Overall, Companio's combination of functional and fun features, along with its direct appeal to family entertainment and assistance, makes it slightly more appealing for a family of four.
#
#
# -----
# a team in company, 5 people group with a manager
# **Ratings:**
#
# - Companio: 8/10
# - Senti: 9/10
#
# **Preference: Senti**
#
# **Explanation:**
#
# Both products offer a range of compelling features designed to improve daily life and interpersonal connections. However, Senti edges ahead due to its focus on emotional connection and meaningful interactions, something that my team and I value significantly.
#
# - **Companio** stands out as a versatile home assistant. Its ability to fetch items, host entertainment, and adapt to the household adds a lot of value, especially for families seeking added convenience and fun during their routines. Its family-friendly and autonomous features are quite appealing. However, while it excels in practical tasks, its focus on emotional connectivity seems less emphasized compared to Senti.
#
# - **Senti** emphasizes emotional connection, appealing to those seeking deeper, human-like interactions through features like “Mood Mirror” and “Shared Rhythm”. Its focus on fostering emotional presence through technology, particularly for long-distance relationships and elderly companionship, resonates strongly with us. The user testimonials highlight its effectiveness in creating a feeling of closeness, which we found very compelling. Its holistic approach to connection and privacy-first philosophy also played a part in prioritizing it over Companio.
